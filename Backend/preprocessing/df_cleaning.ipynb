# %%
import numpy as np
import pandas as pd
from decimal import Decimal

# %%
df_file = pd.read_csv('E:/Alpha/Python/IVW.csv')
# Out:
# C:\Users\prince sahu\AppData\Local\Temp\ipykernel_16864\3380821350.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_file = pd.read_csv('E:/Alpha/Python/IVW.csv')

# %%
df_file
# Out:
#         Unnamed: 0   ticker                           name  \
# 0                0     MSFT                 MICROSOFT CORP
# 1                1     AAPL                      APPLE INC
# 2                2     NVDA                    NVIDIA CORP
# 3                3     AMZN                 AMAZON COM INC
# 4                4     META     META PLATFORMS INC CLASS A
# ...            ...      ...                            ...
# 103035      103035      ARD        ARDAGH GROUP SA CLASS A
# 103036      103036        -  ESC GCI LIBERTY INC SR ESCROW
# 103037      103037  ETD_USD    ETD USD BALANCE WITH R30382
# 103038      103038     FAM4       S&P MID 400 EMINI JUN 24
# 103039      103039     ESM4            S&P500 EMINI JUN 24
#
#                          sector asset_class       market_value  weight  \
# 0        Information Technology      Equity  5,70,14,72,219.05   12.52
# 1        Information Technology      Equity  5,15,80,00,981.50   11.32
# 2        Information Technology      Equity  5,00,53,27,504.90   10.99
# 3        Consumer Discretionary      Equity  2,98,10,63,369.24    6.54
# 4                 Communication      Equity  1,89,83,09,109.06    4.17
# ...                         ...         ...                ...     ...
# 103035                Materials      Equity          88,987.41    0.00
# 103036            Communication      Equity                0.7    0.00
# 103037  Cash and/or Derivatives        Cash               3.12    0.00
# 103038  Cash and/or Derivatives     Futures                  0    0.00
# 103039  Cash and/or Derivatives     Futures                  0    0.00
#
#            notional_value          shares     price       location  \
# 0       5,70,14,72,219.05  1,37,34,185.00    415.13  United States
# 1       5,15,80,00,981.50  2,68,29,654.00    192.25  United States
# 2       5,00,53,27,504.90    45,65,530.00  1,096.33  United States
# 3       2,98,10,63,369.24  1,68,95,621.00    176.44  United States
# 4       1,89,83,09,109.06    40,66,382.00    466.83  United States
# ...                   ...             ...       ...            ...
# 103035          88,987.41       12,001.00      7.42     Luxembourg
# 103036                0.7       70,458.00         0  United States
# 103037               3.12               3       100  United States
# 103038       5,022,650.00              17  2,954.50              -
# 103039      64,858,625.00             239  5,427.50              -
#
#                             exchange currency fx_rate market_currency  \
# 0                             NASDAQ      USD       1             USD
# 1                             NASDAQ      USD       1             USD
# 2                             NASDAQ      USD       1             USD
# 3                             NASDAQ      USD       1             USD
# 4                             NASDAQ      USD       1             USD
# ...                              ...      ...     ...             ...
# 103035  New York Stock Exchange Inc.      USD       1             USD
# 103036                        NASDAQ      USD       1             USD
# 103037                             -      USD       1             USD
# 103038      Index And Options Market      USD       1             USD
# 103039      Index And Options Market      USD       1             USD
#
#        accrual_date etfname      date
# 0                 -     IVW  20240531
# 1                 -     IVW  20240531
# 2                 -     IVW  20240531
# 3                 -     IVW  20240531
# 4                 -     IVW  20240531
# ...             ...     ...       ...
# 103035            -     IWB  20240612
# 103036            -     IWB  20240612
# 103037     1-Jan-00     IWB  20240612
# 103038            -     IWB  20240612
# 103039            -     IWB  20240612
#
# [103040 rows x 18 columns]

# %%
df_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103040 entries, 0 to 103039
# Data columns (total 18 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       103040 non-null  int64
#  1   ticker           103022 non-null  object
#  2   name             103040 non-null  object
#  3   sector           103040 non-null  object
#  4   asset_class      103040 non-null  object
#  5   market_value     103040 non-null  object
#  6   weight           103040 non-null  float64
#  7   notional_value   103040 non-null  object
#  8   shares           103040 non-null  object
#  9   price            103040 non-null  object
#  10  location         103040 non-null  object
#  11  exchange         103040 non-null  object
#  12  currency         103040 non-null  object
#  13  fx_rate          103040 non-null  object
#  14  market_currency  103040 non-null  object
#  15  accrual_date     103040 non-null  object
#  16  etfname          103040 non-null  object
#  17  date             103040 non-null  int64
# dtypes: float64(1), int64(2), object(15)
# memory usage: 14.2+ MB

# %%
df_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103040 entries, 0 to 103039
# Data columns (total 18 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Unnamed: 0       103040 non-null  int64
#  1   ticker           103022 non-null  object
#  2   name             103040 non-null  object
#  3   sector           103040 non-null  object
#  4   asset_class      103040 non-null  object
#  5   market_value     103040 non-null  object
#  6   weight           103040 non-null  float64
#  7   notional_value   103040 non-null  object
#  8   shares           103040 non-null  object
#  9   price            103040 non-null  object
#  10  location         103040 non-null  object
#  11  exchange         103040 non-null  object
#  12  currency         103040 non-null  object
#  13  fx_rate          103040 non-null  object
#  14  market_currency  103040 non-null  object
#  15  accrual_date     103040 non-null  object
#  16  etfname          103040 non-null  object
#  17  date             103040 non-null  int64
# dtypes: float64(1), int64(2), object(15)
# memory usage: 14.2+ MB

# %%
def str_to_int(s):
    
    if isinstance(s, str):
        raw_num=s.replace(',','')
    
        return float(raw_num)
    else:
        return s

# %% [markdown]
# ##### market_value , weight, notional_value ,shares,	price	,fix_rate,
# #####  date -> date_format

# %%
def to_decimal(x):
      try:
        return Decimal(str(x))  # Convert to string before creating Decimal
      except (ValueError, TypeError):
        return None  # Handle non-numeric values (optional)

# %%
def clean_df(df):
    # remove  Empty rows
    df = df.dropna(how='all')  
    # function to convert string values to numbers
    list_of_col=['market_value' , 'weight', 'notional_value' ,'shares',	'price'	,'fx_rate']
    for col_name in (list_of_col):
        df[col_name]=df[col_name].apply(str_to_int)
        df[col_name]=df[col_name].astype("float64")
    # function to convert datetime values to datetime objects

    df['date'] = pd.to_datetime(df['date'], format='%Y%M%d').dt.date

        
    # print(df.head)
    # print(df['date'])
    return df

# %%
clean_df(df_file)
# Out:
# 0         2024-01-31
# 1         2024-01-31
# 2         2024-01-31
# 3         2024-01-31
# 4         2024-01-31
#              ...
# 103035    2024-01-12
# 103036    2024-01-12
# 103037    2024-01-12
# 103038    2024-01-12
# 103039    2024-01-12
# Name: date, Length: 103040, dtype: object

# %%
type("sdg")
# Out:
# str
